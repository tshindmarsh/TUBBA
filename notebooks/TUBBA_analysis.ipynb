# %%
# Path to your 'src' directory
import sys
src_path = '/Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/src'
if src_path not in sys.path:
    sys.path.append(src_path)

# %%
from PyQt5.QtWidgets import QApplication
from TUBBAvidAnn import VideoAnnotator

if __name__ == "__main__":
    app = QApplication(sys.argv)

    # --- Fake project structure
    project = {
        'behaviors': ['Chase', 'Attack', 'Pause','Chase1', 'Attack1', 'Pause1','Chase2', 'Attack2', 'Pause2'],
        'models': {},
        'videos': [
            {
                'name': '/20241220_ms216_PWKC57_BC1_Escape_lowres.mp4',
                'folder': '/Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/data/TrainingData/ms216',
                # <-- Replace this!!
                'nFrames': 89954,
                'frameRate': 50,
                'samplingRate': 0.5,
                'featureFile': 'perframe_feats.h5',
                'annotations': {},
            }
        ]
    }

    # --- Launch Video Annotator
    window = VideoAnnotator(project)
    window.show()

    sys.exit(app.exec_())
# Out:
# Traceback (most recent call last):
#   File "/Applications/PyCharm.app/Contents/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_comm.py", line 744, in make_thread_stack_str
#     if is_real_file(my_file) and not is_jup_cell:
#        ^^^^^^^^^^^^^^^^^^^^^
#   File "/Applications/PyCharm.app/Contents/plugins/python-ce/helpers/pydev/pydevd_file_utils.py", line 559, in is_real_file
#     return not _is_int(filename) and not filename.startswith("<ipython-input")
#                                          ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'tuple' object has no attribute 'startswith'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 26
#       8 project = {
#       9     'behaviors': ['Chase', 'Attack', 'Pause','Chase1', 'Attack1', 'Pause1','Chase2', 'Attack2', 'Pause2'],
#      10     'models': {},
#    (...)     22     ]
#      23 }
# ...

# %%
dir = '/Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/data/TrainingData'

# Get folders inside dir and delete perframe_feats.mat
import os

folders = [os.path.join(dir, d) for d in os.listdir(dir) if os.path.isdir(os.path.join(dir, d))]
folders
# Out:
# ['/Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/data/TrainingData/ms193',
#  '/Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/data/TrainingData/ms194',
#  '/Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/data/TrainingData/ms195',
#  '/Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/data/TrainingData/ms192',
#  '/Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/data/TrainingData/ms217',
#  '/Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/data/TrainingData/ms211',
#  '/Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/data/TrainingData/ms216',
#  '/Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/data/TrainingData/ms218',
#  '/Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/data/TrainingData/ms188',
# ...

# %%
for folder in folders:
    file_to_delete = os.path.join(folder, 'perframe_feats.mat')
    if os.path.exists(file_to_delete):
        print(f"Removing {file_to_delete}...")
        os.remove(file_to_delete)
# Out:
# Removing /Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/data/TrainingData/ms193/perframe_feats.mat...
# Removing /Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/data/TrainingData/ms194/perframe_feats.mat...
# Removing /Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/data/TrainingData/ms195/perframe_feats.mat...
# Removing /Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/data/TrainingData/ms192/perframe_feats.mat...
# Removing /Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/data/TrainingData/ms217/perframe_feats.mat...
# Removing /Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/data/TrainingData/ms211/perframe_feats.mat...
# Removing /Users/tomhs/Documents/LuoLab/HuntingCircuits/Code/PythonProjects/TUBBA/data/TrainingData/ms216/perframe_feats.mat...
# ...
